# %%
from pathlib import Path

import pandas as pd
from sklearn.model_selection import train_test_split

# %%
data_dir = Path("data/zihan")

# %%
df_full = pd.read_pickle(data_dir / "data_20220905_full.pkl")
df_full
# Out:
#                                                     file  chirp   curv  \
# 0      section_CL3_chirp_-7.4399999999999995_curv_281...  -7.44  281.3
# 1      section_CL3_chirp_-7.049999999999999_curv_263....  -7.05  263.7
# 2      section_CL3_chirp_-9.0_curv_247.8_skew_46988.0...  -9.00  247.8
# 3      section_CL3_chirp_-7.26_curv_288.7_skew_44225....  -7.26  288.7
# 4      section_CL3_chirp_-7.629999999999999_curv_288....  -7.63  288.0
# ...                                                  ...    ...    ...
# 31995  section_CL3_chirp_-7.159999999999999_curv_265....  -7.16  265.7
# 31996  section_CL3_chirp_-7.279999999999999_curv_278....  -7.28  278.3
# 31997  section_CL3_chirp_-8.729999999999999_curv_256....  -8.73  256.1
# 31998  section_CL3_chirp_-8.489999999999998_curv_256....  -8.49  256.1
# 31999  section_CL3_chirp_-7.1899999999999995_curv_244...  -7.19  244.7
#
#           skew  chirpL1  chirpL2   slice_width  \
# 0      45442.0   -13.43     2.11  3.026108e-07
# ...

# %%
df_train, df_val_test = train_test_split(df_full, test_size=0.2)
df_val, df_test = train_test_split(df_val_test, test_size=0.5)

# %%
len(df_train), len(df_val), len(df_test)
# Out:
# (25600, 3200, 3200)

# %%
df_train.to_pickle(data_dir / "data_20220905_train.pkl")
df_val.to_pickle(data_dir / "data_20220905_validation.pkl")
df_test.to_pickle(data_dir / "data_20220905_test.pkl")
