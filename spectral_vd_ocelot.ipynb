# %%
import pickle

import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from tensorflow import keras
from tensorflow.keras import layers

from nils.reconstruction_module import cleanup_formfactor
from nils.simulate_spectrometer_signal import get_crisp_signal

# %% [markdown]
# ## Load and Preprocess Data

# %%
with open("ocelot80k.pkl", "rb") as file:
    data = pickle.load(file)

# %%
currents = [(sample["s"][:1000], sample["I"][:1000]) for sample in data]
del data

# %%
# Only keep samples with current profiles that exceed 1 kA
filtered = [(s, current) for s, current in currents if current.max() > 1000]
len(filtered)
# Out:
# 20335

# %%
# Shift center of mass of each current profile onto the origin

def shift_onto_center_of_mass(s, current):
    """Shift a current profile such that its center of mass it at 0."""
    cm = (s * current).sum() / current.sum()
    return s - cm, current

shifted = [shift_onto_center_of_mass(s, current) for s, current in filtered]

# %%
# Interpolate all current profiles onto the same samples of s

limit = max(max(np.abs(s)) for s, _ in shifted)
new_s = np.linspace(-limit, limit, 1000)

interpolated = [(new_s, np.interp(new_s, s, current, left=0, right=0)) for s, current in shifted]

# %%
# Make formfactors
def current2formfactor(s, current):
    """Convert a current to its corresponding cleaned form factor."""
    frequency, formfactor, formfactor_noise, detlim = get_crisp_signal(s, current, n_shots=10, which_set="both")
    clean_frequency, clean_formfactor, _ = cleanup_formfactor(frequency, formfactor, formfactor_noise, detlim, channels_to_remove=[])

    return clean_frequency, clean_formfactor

formfactors = [current2formfactor(*current) for current in interpolated]
# Out:
# /usr/local/lib/python3.8/site-packages/scipy/optimize/minpack.py:828: OptimizeWarning: Covariance of the parameters could not be estimated
#   warnings.warn('Covariance of the parameters could not be estimated',

# %%
X = np.stack([formfactor for _, formfactor in formfactors])
y = np.stack([current for _, current in interpolated])

# %% [markdown]
# ## Training

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=True)

# %%
ff_scaler = MinMaxScaler()
X_train_scaled = ff_scaler.fit_transform(X_train)

current_scaler = 1 / y_train.max(axis=1).mean()
y_train_scaled = y_train * current_scaler

# %%
model = keras.Sequential([
    layers.Dense(200, activation="relu"),
    layers.Dense(100, activation="relu"),
    layers.Dense(50, activation="relu"),
    layers.Dense(y_train.shape[1], activation="relu")]
)
model.compile(optimizer="adam", loss="mse", metrics=["mae"])

# %%
history = model.fit(X_train_scaled, y_train_scaled, epochs=500, batch_size=64, validation_split=0.25)
# Out:
# e: 0.0070
# Epoch 353/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.0011 - mae: 0.0062 - val_loss: 0.0015 - val_mae: 0.0071
# Epoch 354/500
# 191/191 [==============================] - 1s 7ms/step - loss: 0.0011 - mae: 0.0061 - val_loss: 0.0016 - val_mae: 0.0073
# Epoch 355/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0011 - mae: 0.0063 - val_loss: 0.0015 - val_mae: 0.0072
# Epoch 356/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.0011 - mae: 0.0062 - val_loss: 0.0015 - val_mae: 0.0070
# Epoch 357/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.0011 - mae: 0.0061 - val_loss: 0.0015 - val_mae: 0.0072
# Epoch 358/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.0011 - mae: 0.0063 - val_loss: 0.0015 - val_mae: 0.0071
# Epoch 359/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0011 - mae: 0.0062 - val_loss: 0.0016 - val_mae: 0.0074
# Epoch 360/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.0011 - mae: 0.0063 - val_loss: 0.0015 - val_mae: 0.0072
# Epoch 361/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.0011 - mae: 0.0062 - val_loss: 0.0015 - val_mae: 0.0071
# Epoch 362/500
# 191/191 [==============================] - 1s 7ms/step - loss: 0.0011 - mae: 0.0062 - val_loss: 0.0015 - val_mae: 0.0070
# Epoch 363/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.0011 - mae: 0.0062 - val_loss: 0.0016 - val_mae: 0.0074
# Epoch 364/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.0011 - mae: 0.0062 - val_loss: 0.0015 - val_mae: 0.0071
# Epoch 365/500
# 191/191 [==============================] - 1s 8ms/step - loss: 0.0011 - mae: 0.0061 - val_loss: 0.0016 - val_mae: 0.0072
# Epoch 366/500
# 191/191 [==============================] - 2s 8ms/step - loss: 0.0011 - mae: 0.0063 - val_loss: 0.0016 - val_mae: 0.0071
# Epoch 367/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0011 - mae: 0.0063 - val_loss: 0.0015 - val_mae: 0.0071
# Epoch 368/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0011 - mae: 0.0062 - val_loss: 0.0015 - val_mae: 0.0072
# Epoch 369/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0011 - mae: 0.0062 - val_loss: 0.0015 - val_mae: 0.0072
# Epoch 370/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0011 - mae: 0.0061 - val_loss: 0.0015 - val_mae: 0.0072
# Epoch 371/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0011 - mae: 0.0061 - val_loss: 0.0015 - val_mae: 0.0073
# Epoch 372/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0011 - mae: 0.0063 - val_loss: 0.0015 - val_mae: 0.0071
# Epoch 373/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0011 - mae: 0.0062 - val_loss: 0.0016 - val_mae: 0.0073
# Epoch 374/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0011 - mae: 0.0063 - val_loss: 0.0015 - val_mae: 0.0072
# Epoch 375/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0011 - mae: 0.0062 - val_loss: 0.0016 - val_mae: 0.0073
# Epoch 376/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0011 - mae: 0.0062 - val_loss: 0.0015 - val_mae: 0.0070
# Epoch 377/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0011 - mae: 0.0061 - val_loss: 0.0015 - val_mae: 0.0070
# Epoch 378/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0011 - mae: 0.0062 - val_loss: 0.0016 - val_mae: 0.0073
# Epoch 379/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0011 - mae: 0.0062 - val_loss: 0.0015 - val_mae: 0.0071
# Epoch 380/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0011 - mae: 0.0061 - val_loss: 0.0015 - val_mae: 0.0072
# Epoch 381/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0011 - mae: 0.0062 - val_loss: 0.0015 - val_mae: 0.0070
# Epoch 382/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0011 - mae: 0.0061 - val_loss: 0.0015 - val_mae: 0.0070
# Epoch 383/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0011 - mae: 0.0063 - val_loss: 0.0015 - val_mae: 0.0072
# Epoch 384/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.0011 - mae: 0.0061 - val_loss: 0.0015 - val_mae: 0.0070
# Epoch 385/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0011 - mae: 0.0062 - val_loss: 0.0015 - val_mae: 0.0071
# Epoch 386/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0011 - mae: 0.0062 - val_loss: 0.0015 - val_mae: 0.0071
# Epoch 387/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0011 - mae: 0.0061 - val_loss: 0.0015 - val_mae: 0.0070
# Epoch 388/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0011 - mae: 0.0062 - val_loss: 0.0015 - val_mae: 0.0070
# Epoch 389/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0011 - mae: 0.0061 - val_loss: 0.0015 - val_mae: 0.0072
# Epoch 390/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0011 - mae: 0.0061 - val_loss: 0.0015 - val_mae: 0.0070
# Epoch 391/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.0011 - mae: 0.0062 - val_loss: 0.0015 - val_mae: 0.0070
# Epoch 392/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0011 - mae: 0.0061 - val_loss: 0.0015 - val_mae: 0.0071
# Epoch 393/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.0011 - mae: 0.0061 - val_loss: 0.0016 - val_mae: 0.0072
# Epoch 394/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0011 - mae: 0.0061 - val_loss: 0.0015 - val_mae: 0.0071
# Epoch 395/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0011 - mae: 0.0061 - val_loss: 0.0015 - val_mae: 0.0069
# Epoch 396/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0010 - mae: 0.0060 - val_loss: 0.0015 - val_mae: 0.0071
# Epoch 397/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0011 - mae: 0.0061 - val_loss: 0.0015 - val_mae: 0.0072
# Epoch 398/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0011 - mae: 0.0061 - val_loss: 0.0015 - val_mae: 0.0071
# Epoch 399/500
# 191/191 [==============================] - 1s 7ms/step - loss: 0.0011 - mae: 0.0062 - val_loss: 0.0015 - val_mae: 0.0071
# Epoch 400/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0011 - mae: 0.0060 - val_loss: 0.0015 - val_mae: 0.0071
# Epoch 401/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0010 - mae: 0.0060 - val_loss: 0.0015 - val_mae: 0.0071
# Epoch 402/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.0010 - mae: 0.0060 - val_loss: 0.0015 - val_mae: 0.0071
# Epoch 403/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.0011 - mae: 0.0060 - val_loss: 0.0015 - val_mae: 0.0072
# Epoch 404/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0011 - mae: 0.0063 - val_loss: 0.0016 - val_mae: 0.0072
# Epoch 405/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0011 - mae: 0.0062 - val_loss: 0.0015 - val_mae: 0.0070
# Epoch 406/500
# 191/191 [==============================] - 1s 7ms/step - loss: 0.0011 - mae: 0.0062 - val_loss: 0.0015 - val_mae: 0.0071
# Epoch 407/500
# 191/191 [==============================] - 2s 9ms/step - loss: 0.0011 - mae: 0.0062 - val_loss: 0.0015 - val_mae: 0.0072
# Epoch 408/500
# 191/191 [==============================] - 1s 7ms/step - loss: 0.0011 - mae: 0.0062 - val_loss: 0.0015 - val_mae: 0.0070
# Epoch 409/500
# 191/191 [==============================] - 1s 7ms/step - loss: 0.0010 - mae: 0.0060 - val_loss: 0.0015 - val_mae: 0.0070
# Epoch 410/500
# 191/191 [==============================] - 1s 7ms/step - loss: 0.0010 - mae: 0.0060 - val_loss: 0.0015 - val_mae: 0.0070
# Epoch 411/500
# 191/191 [==============================] - 1s 7ms/step - loss: 0.0011 - mae: 0.0062 - val_loss: 0.0015 - val_mae: 0.0071
# Epoch 412/500
# 191/191 [==============================] - 1s 4ms/step - loss: 0.0011 - mae: 0.0061 - val_loss: 0.0015 - val_mae: 0.0072
# Epoch 413/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0011 - mae: 0.0061 - val_loss: 0.0015 - val_mae: 0.0072
# Epoch 414/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.0010 - mae: 0.0060 - val_loss: 0.0015 - val_mae: 0.0072
# Epoch 415/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.0011 - mae: 0.0062 - val_loss: 0.0015 - val_mae: 0.0071
# Epoch 416/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.0010 - mae: 0.0060 - val_loss: 0.0015 - val_mae: 0.0069
# Epoch 417/500
# 191/191 [==============================] - 1s 7ms/step - loss: 0.0010 - mae: 0.0060 - val_loss: 0.0015 - val_mae: 0.0071
# Epoch 418/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.0011 - mae: 0.0062 - val_loss: 0.0015 - val_mae: 0.0069
# Epoch 419/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0010 - mae: 0.0059 - val_loss: 0.0015 - val_mae: 0.0069
# Epoch 420/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0010 - mae: 0.0059 - val_loss: 0.0015 - val_mae: 0.0069
# Epoch 421/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0011 - mae: 0.0061 - val_loss: 0.0015 - val_mae: 0.0070
# Epoch 422/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.0012 - mae: 0.0066 - val_loss: 0.0015 - val_mae: 0.0071
# Epoch 423/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.0010 - mae: 0.0060 - val_loss: 0.0015 - val_mae: 0.0071
# Epoch 424/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.0010 - mae: 0.0060 - val_loss: 0.0015 - val_mae: 0.0069
# Epoch 425/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.0010 - mae: 0.0060 - val_loss: 0.0015 - val_mae: 0.0070
# Epoch 426/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.0010 - mae: 0.0060 - val_loss: 0.0015 - val_mae: 0.0070
# Epoch 427/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0011 - mae: 0.0061 - val_loss: 0.0015 - val_mae: 0.0071
# Epoch 428/500
# 191/191 [==============================] - 1s 7ms/step - loss: 0.0011 - mae: 0.0060 - val_loss: 0.0015 - val_mae: 0.0072
# Epoch 429/500
# 191/191 [==============================] - 2s 8ms/step - loss: 0.0011 - mae: 0.0061 - val_loss: 0.0015 - val_mae: 0.0069
# Epoch 430/500
# 191/191 [==============================] - 1s 7ms/step - loss: 0.0010 - mae: 0.0060 - val_loss: 0.0015 - val_mae: 0.0070
# Epoch 431/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.0010 - mae: 0.0060 - val_loss: 0.0015 - val_mae: 0.0072
# Epoch 432/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.0011 - mae: 0.0060 - val_loss: 0.0015 - val_mae: 0.0071
# Epoch 433/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.0011 - mae: 0.0061 - val_loss: 0.0015 - val_mae: 0.0070
# Epoch 434/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.0011 - mae: 0.0061 - val_loss: 0.0015 - val_mae: 0.0071
# Epoch 435/500
# 191/191 [==============================] - 2s 10ms/step - loss: 0.0011 - mae: 0.0061 - val_loss: 0.0015 - val_mae: 0.0071
# Epoch 436/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.0011 - mae: 0.0062 - val_loss: 0.0015 - val_mae: 0.0071
# Epoch 437/500
# 191/191 [==============================] - 1s 7ms/step - loss: 0.0010 - mae: 0.0060 - val_loss: 0.0015 - val_mae: 0.0069
# Epoch 438/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0010 - mae: 0.0060 - val_loss: 0.0015 - val_mae: 0.0070
# Epoch 439/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0010 - mae: 0.0059 - val_loss: 0.0015 - val_mae: 0.0070
# Epoch 440/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0010 - mae: 0.0060 - val_loss: 0.0015 - val_mae: 0.0071
# Epoch 441/500
# 191/191 [==============================] - 1s 4ms/step - loss: 0.0010 - mae: 0.0059 - val_loss: 0.0015 - val_mae: 0.0069
# Epoch 442/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0011 - mae: 0.0060 - val_loss: 0.0015 - val_mae: 0.0070
# Epoch 443/500
# 191/191 [==============================] - 1s 4ms/step - loss: 0.0011 - mae: 0.0062 - val_loss: 0.0015 - val_mae: 0.0072
# Epoch 444/500
# 191/191 [==============================] - 1s 4ms/step - loss: 0.0011 - mae: 0.0062 - val_loss: 0.0015 - val_mae: 0.0071
# Epoch 445/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0010 - mae: 0.0060 - val_loss: 0.0015 - val_mae: 0.0070
# Epoch 446/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.0010 - mae: 0.0060 - val_loss: 0.0015 - val_mae: 0.0069
# Epoch 447/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0010 - mae: 0.0059 - val_loss: 0.0015 - val_mae: 0.0072
# Epoch 448/500
# 191/191 [==============================] - 1s 4ms/step - loss: 0.0011 - mae: 0.0060 - val_loss: 0.0015 - val_mae: 0.0071
# Epoch 449/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0010 - mae: 0.0060 - val_loss: 0.0015 - val_mae: 0.0071
# Epoch 450/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0010 - mae: 0.0059 - val_loss: 0.0015 - val_mae: 0.0069
# Epoch 451/500
# 191/191 [==============================] - 1s 7ms/step - loss: 0.0010 - mae: 0.0060 - val_loss: 0.0015 - val_mae: 0.0070
# Epoch 452/500
# 191/191 [==============================] - 2s 9ms/step - loss: 0.0011 - mae: 0.0063 - val_loss: 0.0015 - val_mae: 0.0071
# Epoch 453/500
# 191/191 [==============================] - 2s 8ms/step - loss: 0.0011 - mae: 0.0060 - val_loss: 0.0015 - val_mae: 0.0069
# Epoch 454/500
# 191/191 [==============================] - 1s 6ms/step - loss: 0.0010 - mae: 0.0059 - val_loss: 0.0015 - val_mae: 0.0068
# Epoch 455/500
# 191/191 [==============================] - 1s 7ms/step - loss: 0.0010 - mae: 0.0059 - val_loss: 0.0015 - val_mae: 0.0068
# Epoch 456/500
# 191/191 [==============================] - 1s 4ms/step - loss: 0.0010 - mae: 0.0059 - val_loss: 0.0015 - val_mae: 0.0071
# Epoch 457/500
# 191/191 [==============================] - 1s 4ms/step - loss: 0.0011 - mae: 0.0061 - val_loss: 0.0015 - val_mae: 0.0069
# Epoch 458/500
# 191/191 [==============================] - 1s 4ms/step - loss: 0.0010 - mae: 0.0060 - val_loss: 0.0015 - val_mae: 0.0069
# Epoch 459/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0011 - mae: 0.0061 - val_loss: 0.0016 - val_mae: 0.0073
# Epoch 460/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0011 - mae: 0.0061 - val_loss: 0.0015 - val_mae: 0.0070
# Epoch 461/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0010 - mae: 0.0060 - val_loss: 0.0015 - val_mae: 0.0069
# Epoch 462/500
# 191/191 [==============================] - 1s 4ms/step - loss: 0.0010 - mae: 0.0058 - val_loss: 0.0015 - val_mae: 0.0069
# Epoch 463/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0010 - mae: 0.0059 - val_loss: 0.0015 - val_mae: 0.0069
# Epoch 464/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0010 - mae: 0.0060 - val_loss: 0.0015 - val_mae: 0.0069
# Epoch 465/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0011 - mae: 0.0060 - val_loss: 0.0015 - val_mae: 0.0071
# Epoch 466/500
# 191/191 [==============================] - 1s 4ms/step - loss: 0.0011 - mae: 0.0062 - val_loss: 0.0015 - val_mae: 0.0069
# Epoch 467/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0010 - mae: 0.0059 - val_loss: 0.0015 - val_mae: 0.0070
# Epoch 468/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0010 - mae: 0.0059 - val_loss: 0.0015 - val_mae: 0.0072
# Epoch 469/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0011 - mae: 0.0062 - val_loss: 0.0015 - val_mae: 0.0071
# Epoch 470/500
# 191/191 [==============================] - 1s 4ms/step - loss: 0.0010 - mae: 0.0060 - val_loss: 0.0015 - val_mae: 0.0071
# Epoch 471/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0011 - mae: 0.0062 - val_loss: 0.0015 - val_mae: 0.0071
# Epoch 472/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0010 - mae: 0.0059 - val_loss: 0.0015 - val_mae: 0.0070
# Epoch 473/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0010 - mae: 0.0059 - val_loss: 0.0015 - val_mae: 0.0069
# Epoch 474/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0010 - mae: 0.0059 - val_loss: 0.0015 - val_mae: 0.0069
# Epoch 475/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0011 - mae: 0.0060 - val_loss: 0.0014 - val_mae: 0.0068
# Epoch 476/500
# 191/191 [==============================] - 1s 5ms/step - loss: 9.9058e-04 - mae: 0.0058 - val_loss: 0.0015 - val_mae: 0.0069
# Epoch 477/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0010 - mae: 0.0059 - val_loss: 0.0015 - val_mae: 0.0069
# Epoch 478/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0010 - mae: 0.0059 - val_loss: 0.0015 - val_mae: 0.0071
# Epoch 479/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0011 - mae: 0.0060 - val_loss: 0.0015 - val_mae: 0.0070
# Epoch 480/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0010 - mae: 0.0059 - val_loss: 0.0015 - val_mae: 0.0070
# Epoch 481/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0010 - mae: 0.0059 - val_loss: 0.0015 - val_mae: 0.0070
# Epoch 482/500
# 191/191 [==============================] - 1s 4ms/step - loss: 0.0011 - mae: 0.0061 - val_loss: 0.0015 - val_mae: 0.0069
# Epoch 483/500
# 191/191 [==============================] - 1s 4ms/step - loss: 0.0010 - mae: 0.0060 - val_loss: 0.0016 - val_mae: 0.0074
# Epoch 484/500
# 191/191 [==============================] - 1s 4ms/step - loss: 0.0011 - mae: 0.0061 - val_loss: 0.0014 - val_mae: 0.0068
# Epoch 485/500
# 191/191 [==============================] - 1s 5ms/step - loss: 9.9810e-04 - mae: 0.0058 - val_loss: 0.0014 - val_mae: 0.0068
# Epoch 486/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0010 - mae: 0.0058 - val_loss: 0.0015 - val_mae: 0.0069
# Epoch 487/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0010 - mae: 0.0059 - val_loss: 0.0014 - val_mae: 0.0068
# Epoch 488/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0010 - mae: 0.0059 - val_loss: 0.0015 - val_mae: 0.0070
# Epoch 489/500
# 191/191 [==============================] - 1s 4ms/step - loss: 0.0011 - mae: 0.0061 - val_loss: 0.0015 - val_mae: 0.0070
# Epoch 490/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0011 - mae: 0.0061 - val_loss: 0.0015 - val_mae: 0.0071
# Epoch 491/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0011 - mae: 0.0063 - val_loss: 0.0015 - val_mae: 0.0071
# Epoch 492/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0010 - mae: 0.0059 - val_loss: 0.0015 - val_mae: 0.0070
# Epoch 493/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0010 - mae: 0.0058 - val_loss: 0.0015 - val_mae: 0.0069
# Epoch 494/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0010 - mae: 0.0058 - val_loss: 0.0015 - val_mae: 0.0070
# Epoch 495/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0010 - mae: 0.0059 - val_loss: 0.0015 - val_mae: 0.0070
# Epoch 496/500
# 191/191 [==============================] - 2s 8ms/step - loss: 0.0012 - mae: 0.0060 - val_loss: 0.0015 - val_mae: 0.0070
# Epoch 497/500
# 191/191 [==============================] - 2s 10ms/step - loss: 0.0010 - mae: 0.0060 - val_loss: 0.0015 - val_mae: 0.0071
# Epoch 498/500
# 191/191 [==============================] - 1s 7ms/step - loss: 0.0011 - mae: 0.0061 - val_loss: 0.0015 - val_mae: 0.0068
# Epoch 499/500
# 191/191 [==============================] - 1s 5ms/step - loss: 0.0011 - mae: 0.0061 - val_loss: 0.0015 - val_mae: 0.0070
# Epoch 500/500
# 191/191 [==============================] - 2s 9ms/step - loss: 0.0010 - mae: 0.0058 - val_loss: 0.0015 - val_mae: 0.0068

# %%
plt.figure(figsize=(14,4))
plt.subplot(121)
plt.title("Loss (MSE)")
plt.plot(history.history["loss"], label="Training")
plt.plot(history.history["val_loss"], label="Validation")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.grid()
plt.subplot(122)
plt.title("MAE")
plt.plot(history.history["mae"], label="Training")
plt.plot(history.history["val_mae"], label="Validation")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## Quick Test

# %%
X_test_scaled = ff_scaler.transform(X_test)
y_predict_scaled = model.predict(X_test_scaled)
y_predict = y_predict_scaled / current_scaler

# %%
samples = np.random.randint(0, len(y_predict), size=3)

plt.figure(figsize=(21,4))
for i, sample in enumerate(samples):
    plt.subplot(1, 3, i+1)
    plt.title(f"Sample {sample}")
    plt.plot(new_s*1e6, y_test[sample]*1e-3, ls="--", label="Ground Truth")
    plt.plot(new_s*1e6, y_predict[sample]*1e-3, label="Prediction")
    plt.xlabel("s (μm)")
    plt.ylabel("Current (kA)")
    plt.legend()
    plt.grid()
plt.show()

# %% [markdown]
# ## Evaluation

# %%
X_test_scaled = ff_scaler.transform(X_test)
y_test_scaled = y_test * current_scaler

# %%
score = model.evaluate(X_test_scaled, y_test_scaled, batch_size=64)
# Out:
# 64/64 [==============================] - 0s 3ms/step - loss: 0.0013 - mae: 0.0066
